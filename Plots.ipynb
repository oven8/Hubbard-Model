# %%
import numpy as np
import cmath as cm
import matplotlib.pyplot as plt
plt.rcParams.update({
    "text.usetex": True,
    "font.family": "Palatino"
})

# %%
mag1 = [0.25, 0.24955629299160814, 0.2482165434955703, 0.24595392720250056, 0.24271947260412963, 0.23843219676046265, 0.23295951755403035, 0.22608507168670347, 0.21746620261470198, 0.2065936745028841, 0.19278500157887024, 0.17527213612827858, 0.15341776833349047, 0.12690630189454086, 0.10038306010039451, 0.08212677178291336, 0.06936253000298684, 0.05976133513919801, 0.052252389959278396, 0.046224918622775724, 0.04129005996049463]
mag2 = [0.25, 0.24955843758642676, 0.24822500623526558, 0.24597221961358545, 0.24274891280236438, 0.23846833026098774, 0.23298411170147618, 0.22604781056872156, 0.217240352743904, 0.20586615073813577, 0.1907802517848158, 0.17003995606463593, 0.13966116123314187, 0.08807399255340147, 0.024522294806447822, 0.004150365248369304, 0.0008542506552955673, 0.000249781051162786, 0.00010053718049776244, 5.240842765004733e-5, 3.1979483737044575e-5]
g = np.arange(0,1.01,0.05)

# %%
f2 = plt.figure()
plt.plot(g,mag1,color='red',label=r'$i=4,j=6$')
plt.plot(g,mag2,color='blue',label=r'$i=4,j=40$')
plt.margins(0)
plt.legend()
plt.xlabel(r'$g$')
plt.ylabel(r'$\left< S_i^zS_j^z\right>$')
f2.savefig('corrMIsing.pdf',bbox_inches='tight')

# %%
data = [1.6329818517963893e-8,-5.492090478578346e-10,-6.118938752033743e-8,1.2814769305077388e-6,1.2814769305077388e-6,-0.0006403614960518736,-0.4956831933319623,-0.6599041786610653,-0.724892358538684,0.7722575898170039,-0.8108647408640848,-0.8458869977154104,-0.8767072866932653,-0.9058699696164909,-0.9330670736570684,0.958669413816326,-0.9831758035587956,-1.0064852590012232,-1.0286553035179062,1.0504874457393856,-1.0714034132928756]
data = np.array(data)
J = np.arange(0,0.41,0.02)

# %%
f1 = plt.figure()
plt.plot(J,np.abs(data))
plt.axvline(x=0.1, color='r', linestyle='--')
plt.text(0.04, 0.4, 'MI', color='r')
plt.text(0.26, 0.4, 'SF', color='r')
plt.margins(0)
plt.xlabel(r'$J/U$')
plt.ylabel(r'Order Parameter $|\left< \hat{a}_6\right>|$')
f1.savefig('PhaseBH.pdf',bbox_inches='tight')
